# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
TOP_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))
if TOP_DIR not in sys.path:
    sys.path.insert(0, TOP_DIR)
from causalign.data import visualize
DB_PATH = os.path.abspath(os.path.join(os.getcwd(), "..", "causalign", "out", "experiments.db"))
print(f"Database path: {DB_PATH}")
# Out:
# Database path: /Users/danielfrees/Desktop/causalign/causalign/out/experiments.db

# %% [markdown]
# # Load Experiments DB

# %%
arguments_df = visualize.load_data_from_db("arguments", db_path=DB_PATH)
metrics_df = visualize.load_data_from_db("metrics", db_path=DB_PATH)
PROJECT_NAME = 

# Display some basic information
print("Arguments Data:")
print(arguments_df.head())

print("Metrics Data:")
print(metrics_df.head())
# Out:
# Arguments Data:
#    id            timestamp                         arg_pretrained_model_name  \
# 0   1  2024-11-26 02:41:48  sentence-transformers/msmarco-distilbert-base-v4
# 1   2  2024-11-26 02:48:33  sentence-transformers/msmarco-distilbert-base-v4
# 2   3  2024-11-26 04:02:31  sentence-transformers/msmarco-distilbert-base-v4
# 3   4  2024-11-26 04:18:36  sentence-transformers/msmarco-distilbert-base-v4
# 4   5  2024-11-26 05:31:13  sentence-transformers/msmarco-distilbert-base-v4
#
#   arg_unfreeze_backbone arg_sentiment_head_type arg_riesz_head_type arg_seed  \
# 0                  top0                     fcn                 fcn    11711
# 1                  top0                     fcn                 fcn    11711
# 2                  top0                     fcn                 fcn    11711
# 3                  top0                  linear                 fcn    11711
# 4                  top0                  linear                 fcn    11711
#
#   arg_use_gpu arg_autocast arg_num_workers  ... arg_early_stop_delta  \
# 0        True        False              14  ...                  0.1
# 1        True        False              14  ...                  0.1
# 2        True        False              14  ...                 0.05
# 3        True        False              14  ...                 0.05
# 4        True        False              14  ...                 0.05
#
#   arg_dataset arg_max_seq_length arg_treatment_phrase arg_lambda_bce  \
# 0        imdb                150                 love            1.0
# 1        imdb                150                 love            1.0
# 2        imdb                150                 love            1.0
# 3        imdb                150                 love            1.0
# 4        imdb                150                 love            1.0
#
#   arg_lambda_reg arg_lambda_riesz arg_running_ate  \
# 0           0.01             0.01           False
# 1           0.01             0.01           False
# 2           0.01             0.01            True
# 3           0.01             0.01           False
# 4           0.01             0.01            True
#
#   arg_estimate_targets_for_ate arg_doubly_robust
# 0                        False              None
# 1                        False              None
# 2                        False              None
# 3                        False              None
# 4                        False              None
#
# [5 rows x 27 columns]
# Metrics Data:
#    id  experiment_id  train_acc  train_f1  val_acc    val_f1  test_acc  \
# 0   1              2    0.90500  0.906643   0.7920  0.798215   0.76248
# 1   2              4    0.76235  0.766632   0.7578  0.761379   0.75008
# 2   3             12    0.93080  0.930354   0.7962  0.795832   0.75496
# 3   4             13    0.76705  0.772053   0.7632  0.767296   0.75408
# 4   5             14    0.95630  0.957482   0.8140  0.825056   0.78112
#
#     test_f1
# 0  0.768065
# 1  0.753492
# 2  0.751541
# 3  0.759015
# 4  0.791352

# %% [markdown]
# # Visualize Results Across Experiments & Hyperparameters

# %%
# ===== simple metrics vs. experiment # =======

visualize.plot_final_metrics(metrics_df)

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "sentiment_head_type"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "riesz_head_type"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "unfreeze_backbone"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "running_ate"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "pretrained_model_name"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")
