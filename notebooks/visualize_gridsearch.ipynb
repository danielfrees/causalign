# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
TOP_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))
if TOP_DIR not in sys.path:
    sys.path.insert(0, TOP_DIR)
from causalign.data import visualize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Experiments DB

# %%
arguments_df = visualize.load_data_from_db("arguments")
metrics_df = visualize.load_data_from_db("metrics")

# Display some basic information
print("Arguments Data:")
print(arguments_df.head())

print("Metrics Data:")
print(metrics_df.head())
# Out:
# Arguments Data:
#    id            timestamp  ... arg_running_ate arg_estimate_targets_for_ate
# 0   1  2024-11-25 22:07:50  ...           False                        False
# 1   2  2024-11-25 22:16:44  ...           False                        False
# 2   3  2024-11-25 22:26:40  ...           False                        False
# 3   4  2024-11-25 22:28:10  ...           False                        False
# 4   5  2024-11-25 22:29:12  ...           False                        False
#
# [5 rows x 26 columns]
# Metrics Data:
#    id  experiment_id  train_acc  ...    val_f1  test_acc   test_f1
# 0   1             16      0.800  ...  0.782906     0.742  0.787479
# 1   2             17      0.594  ...  0.354286     0.538  0.334294
#
# [2 rows x 8 columns]

# %% [markdown]
# # Visualize Results Across Experiments & Hyperparameters

# %%
# ===== simple metrics vs. experiment # =======

visualize.plot_final_metrics(metrics_df)

# %%
# ====== Analyze metrics vs hyperparameters ============

# try diff ones out here:
hyperparameter_to_analyze = "treatment_phrase"  
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "test")
visualize.plot_metrics_vs_hyperparameters(arguments_df, metrics_df, hyperparameter_to_analyze, split = "val")
