# %% [markdown]
# # EDA of Longform Text Alignment Datasets

# %%
import pandas as pd 
import numpy as np
import os

# %%
TOP_DIR = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))

# %%
df_cit = pd.read_parquet(os.path.join(TOP_DIR, 'data', 'acl_full_citations.parquet'))
df_pub = pd.read_parquet(os.path.join(TOP_DIR, 'data', 'acl-publication-info.74k.v2.parquet'))

# %%
df_cit.head()
# Out:
#            id  citingpaperid  citedpaperid  is_citedpaperid_acl  \
# 0   868703600       52046747      16228715                 True
# 1  3216252045      229723601       1373518                 True
# 2   437616166       16841192        629094                 True
# 3  3349792001      235196103      19121210                 True
# 4  3313665988      233365331     218974137                 True
#
#    is_citingpaperid_acl
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                  True

# %%
df_pub.head()
# Out:
#      acl_id                                           abstract  \
# 0  O02-2002  There is a need to measure word similarity whe...
# 1  L02-1310                                               None
# 2  R13-1042  Thread disentanglement is the task of separati...
# 3  W05-0819  In this paper, we describe a word alignment al...
# 4  L02-1309                                               None
#
#                                            full_text  corpus_paper_id  \
# 0  There is a need to measure word similarity whe...         18022704
# 1                                               None          8220988
# 2  Thread disentanglement is the task of separati...         16703040
# 3  In this paper, we describe a word alignment al...          1215281
# 4                                               None         18078432
#
#                                    pdf_hash  numcitedby  \
# 0  0b09178ac8d17a92f16140365363d8df88c757d0          14
# ...

# %%
df_c_short = df_cit[(df_cit['is_citedpaperid_acl'] == True) & (df_cit['is_citingpaperid_acl'] == True)].head(100)

# %%
matched_abstracts = df_c_short = df_c_short[['citingpaperid', 'citedpaperid']].merge(
    df_pub[['corpus_paper_id', 'abstract']].rename(columns={'abstract': 'citing_abstract'}),
    left_on="citingpaperid", right_on="corpus_paper_id", how='left'
).merge(
    df_pub[['corpus_paper_id', 'abstract']].rename(columns={'abstract': 'cited_abstract'}),
    left_on="citedpaperid", right_on="corpus_paper_id", how='left'
)

# %%
matched_abstracts.head()
# Out:
#    citingpaperid  citedpaperid  corpus_paper_id_x  \
# 0      233365331     218974137          233365331
# 1        3841628      18998986            3841628
# 2      218974058     204896994          218974058
# 3       53242563      15453873           53242563
# 4        1009868        680757            1009868
#
#                                      citing_abstract  corpus_paper_id_y  \
# 0  In this work we compare the performance of con...          218974137
# 1  Election manifestos document the intentions, m...           18998986
# 2  In this paper we describe our work on the deve...          204896994
# 3  We posed the shared task of assigning sentence...           15453873
# 4  We present the results of the WMT13 shared tas...             680757
#
#                                       cited_abstract
# 0  There is an increasing demand for sentiment an...
# 1  In recent years, keyphrase extraction has rece...
# 2  In order to automatically extend a treebank of...
# ...

# %%
len(matched_abstracts)
# Out:
# 100
